# %%
import requests
import re
from bs4 import BeautifulSoup as bs

# %%
url = requests.get('https://www.youtube.com/watch?v=oJkR5z50RZU')

# %%
text = url.text
print(text)
# Out:
# <!DOCTYPE html><html lang="zh-TW" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}</style><script name="www-roboto" >if (document.fonts && document.fonts.load) {doc
# ...

# %%
m = re.search('"args":({.*?}),',text)

# %%
print(m.group(1))
# Out:
# {"fexp":"23723207,23735282,23735348,23736685,23744176,23751767,23752869,23755886,23755898,23758152,23762649,23780988,23782268,23785333,23786469,23788848,23790663,23791804,23791804,23794557,23802148,23804295,23804498,23806568,23806682,23806682,23807250,23807442,23807949,23808680,23808924,23809083,23809469,23809745,9417827,9445879,9449243,9450144,9471239","host_language":"zh-TW","enabled_engage_types":"3,6,4,5,17,1","author":"Izumi Miyuki","hl":"zh_TW","cver":"1.20190423","loudness":"-16.2889995575","ucid":"UCOJZXix0U1fAbw60zrP7aMw","innertube_context_client_version":"1.20190423","url_encoded_fmt_stream_map":"url=https%3A%2F%2Fr5---sn-ipoxu-3ii6.googlevideo.com%2Fvideoplayback%3Fms%3Dau%252Crdu%26requiressl%3Dyes%26mt%3D1556282660%26pl%3D20%26itag%3D18%26id%3Do-AAOU1Zo_8qtjKJcAN9TYqLP1uVmNtGbwWUM8w1Ntnwxh%26dur%3D249.173%26mime%3Dvideo%252Fmp4%26c%3DWEB%26sparams%3Dclen%252Cdur%252Cei%252Cgir%252Cid%252Cinitcwndbps%252Cip%252Cipbits%252Citag%252Clmt%252Cmime%252Cmm%252Cmn%252Cms%252Cmv
# ...

# %%
string = m.group(1).split(',"player_response')[0]
string = string+'}'
print(string)
# Out:
# {"fexp":"23723207,23735282,23735348,23736685,23744176,23751767,23752869,23755886,23755898,23758152,23762649,23780988,23782268,23785333,23786469,23788848,23790663,23791804,23791804,23794557,23802148,23804295,23804498,23806568,23806682,23806682,23807250,23807442,23807949,23808680,23808924,23809083,23809469,23809745,9417827,9445879,9449243,9450144,9471239","host_language":"zh-TW","enabled_engage_types":"3,6,4,5,17,1","author":"Izumi Miyuki","hl":"zh_TW","cver":"1.20190423","loudness":"-16.2889995575","ucid":"UCOJZXix0U1fAbw60zrP7aMw","innertube_context_client_version":"1.20190423","url_encoded_fmt_stream_map":"url=https%3A%2F%2Fr5---sn-ipoxu-3ii6.googlevideo.com%2Fvideoplayback%3Fms%3Dau%252Crdu%26requiressl%3Dyes%26mt%3D1556282660%26pl%3D20%26itag%3D18%26id%3Do-AAOU1Zo_8qtjKJcAN9TYqLP1uVmNtGbwWUM8w1Ntnwxh%26dur%3D249.173%26mime%3Dvideo%252Fmp4%26c%3DWEB%26sparams%3Dclen%252Cdur%252Cei%252Cgir%252Cid%252Cinitcwndbps%252Cip%252Cipbits%252Citag%252Clmt%252Cmime%252Cmm%252Cmn%252Cms%252Cmv
# ...

# %%
import json
jd = json.loads(m.group(1))
print(jd['url_encoded_fmt_stream_map'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-79-e1dddc5c92de> in <module>
#       1 import json
# ----> 2 jd = json.loads(m.group(1))
#       3 print(jd['url_encoded_fmt_stream_map'])
#
# D:\anaconda\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# D:\anaconda\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ...

# %%
print(m.group(1)[44330:])
# Out:
# player_response":"{\"playabilityStatus\":{\"status\":\"OK\",\"playableInEmbed\":true}

# %%
import json
jd = json.loads(string)
print(jd['url_encoded_fmt_stream_map'])
# Out:
# url=https%3A%2F%2Fr5---sn-ipoxu-3ii6.googlevideo.com%2Fvideoplayback%3Fms%3Dau%252Crdu%26requiressl%3Dyes%26mt%3D1556282660%26pl%3D20%26itag%3D18%26id%3Do-AAOU1Zo_8qtjKJcAN9TYqLP1uVmNtGbwWUM8w1Ntnwxh%26dur%3D249.173%26mime%3Dvideo%252Fmp4%26c%3DWEB%26sparams%3Dclen%252Cdur%252Cei%252Cgir%252Cid%252Cinitcwndbps%252Cip%252Cipbits%252Citag%252Clmt%252Cmime%252Cmm%252Cmn%252Cms%252Cmv%252Cpl%252Cratebypass%252Crequiressl%252Csource%252Cexpire%26mm%3D31%252C29%26ip%3D1.172.192.241%26mn%3Dsn-ipoxu-3ii6%252Csn-un57sn76%26ei%3Dh_3CXMvDD8P2qAHorJ1Y%26mv%3Dm%26key%3Dyt6%26txp%3D5431432%26initcwndbps%3D807500%26expire%3D1556304359%26ratebypass%3Dyes%26clen%3D22109294%26fvip%3D5%26source%3Dyoutube%26signature%3DC0B2BD805732338D90D69595916BA224BB83F7A0.85BC9BDDBDA451A42B19C3F99A0BF1B82F773801%26lmt%3D1552464763290469%26ipbits%3D0%26gir%3Dyes&itag=18&type=video%2Fmp4%3B+codecs%3D%22avc1.42001E%2C+mp4a.40.2%22&quality=medium

# %%
import urllib
a=urllib.parse.parse_qs(jd['url_encoded_fmt_stream_map'])

# %%
print(a)
# Out:
# {'url': ['https://r5---sn-ipoxu-3ii6.googlevideo.com/videoplayback?ms=au%2Crdu&requiressl=yes&mt=1556282660&pl=20&itag=18&id=o-AAOU1Zo_8qtjKJcAN9TYqLP1uVmNtGbwWUM8w1Ntnwxh&dur=249.173&mime=video%2Fmp4&c=WEB&sparams=clen%2Cdur%2Cei%2Cgir%2Cid%2Cinitcwndbps%2Cip%2Cipbits%2Citag%2Clmt%2Cmime%2Cmm%2Cmn%2Cms%2Cmv%2Cpl%2Cratebypass%2Crequiressl%2Csource%2Cexpire&mm=31%2C29&ip=1.172.192.241&mn=sn-ipoxu-3ii6%2Csn-un57sn76&ei=h_3CXMvDD8P2qAHorJ1Y&mv=m&key=yt6&txp=5431432&initcwndbps=807500&expire=1556304359&ratebypass=yes&clen=22109294&fvip=5&source=youtube&signature=C0B2BD805732338D90D69595916BA224BB83F7A0.85BC9BDDBDA451A42B19C3F99A0BF1B82F773801&lmt=1552464763290469&ipbits=0&gir=yes'], 'itag': ['18'], 'type': ['video/mp4; codecs="avc1.42001E, mp4a.40.2"'], 'quality': ['medium']}

# %%
finalurl = a['url'][0]
req = requests.get(finalurl,stream=True)
with open('D:/test/test.mp4','wb') as f:
    f.write(req.content)

# %%
s='https%3A%2F%2Fr5---sn-ipoxu-3ii6.googlevideo.com%2Fvideoplayback%3Fms%3Dau%252Crdu%26requiressl%3Dyes%26mt%3D1556282660%26pl%3D20%26itag%3D248%26id%3Do-AAOU1Zo_8qtjKJcAN9TYqLP1uVmNtGbwWUM8w1Ntnwxh%26dur%3D249.082%26aitags%3D133%252C134%252C135%252C136%252C137%252C160%252C242%252C243%252C244%252C247%252C248%252C278%252C298%252C299%252C302%252C303%26mime%3Dvideo%252Fwebm%26c%3DWEB%26sparams%3Daitags%252Cclen%252Cdur%252Cei%252Cgir%252Cid%252Cinitcwndbps%252Cip%252Cipbits%252Citag%252Ckeepalive%252Clmt%252Cmime%252Cmm%252Cmn%252Cms%252Cmv%252Cpl%252Crequiressl%252Csource%252Cexpire%26mm%3D31%252C29%26ip%3D1.172.192.241%26mn%3Dsn-ipoxu-3ii6%252Csn-un57sn76%26ei%3Dh_3CXMvDD8P2qAHorJ1Y%26mv%3Dm%26key%3Dyt6%26keepalive%3Dyes%26txp%3D5431432%26initcwndbps%3D807500%26expire%3D1556304359%26clen%3D55612762%26fvip%3D5%26source%3Dyoutube%26signature%3D097C9B9A1B8687DC1E90B5A924ADAF15DEB0D70A.8CB0C587D3DCFD2BB1C9C84F8EEA7A461C2B8592%26lmt%3D1552466049252496%26ipbits%3D0%26gir%3Dyes\u0026xtags=\u0026quality_label=1080p\u0026itag=248\u0026init=0-219\u0026clen=55612762\u0026fps=30\u0026primaries=bt709\u0026eotf=bt709\u0026projection_type=1\u0026index=220-1076\u0026bitrate=1927623\u0026size=1920x1080\u0026lmt=1552466049252496\u0026type=video%2Fwebm%3B+codecs%3D%22vp9%22'
testa = urllib.parse.parse_qs(s)
print(testa)
# Out:
# {'quality_label': ['1080p'], 'itag': ['248'], 'init': ['0-219'], 'clen': ['55612762'], 'fps': ['30'], 'primaries': ['bt709'], 'eotf': ['bt709'], 'projection_type': ['1'], 'index': ['220-1076'], 'bitrate': ['1927623'], 'size': ['1920x1080'], 'lmt': ['1552466049252496'], 'type': ['video/webm; codecs="vp9"']}
